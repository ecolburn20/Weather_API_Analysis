# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
from datetime import datetime

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 608

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial" 
query_url = f"{url}appid={api_key}&units={units}&q="
city_name = []
i = 0
j = 1
# Loop through the list of cities and perform a request for data on each
for city in cities:
    response = requests.get(query_url + city).json()
    
    if i < 50:
        try:
            name = response['name']
            print(f"Processing Record {i} of Set {j} | {name}")
            city_name.append(name)
            i = i+1
        except (KeyError, IndexError):
            print("City not found. Skipping...") 
        
    else:

        try:
            name = response['name']
            i = 0
            j = j+1
            print(f"Processing Record {i} of Set {j} | {name}")
            city_name.append(name)
            i = 1
        except (KeyError, IndexError):
            print("City not found. Skipping...") 
    time.sleep(1)
print('---------------------------')
print('Data Retrieval Complete')
print('---------------------------')
# Out:
# Processing Record 0 of Set 1 | Carnarvon
# Processing Record 1 of Set 1 | Hermanus
# Processing Record 2 of Set 1 | Barrow
# City not found. Skipping...
# Processing Record 3 of Set 1 | Hithadhoo
# Processing Record 4 of Set 1 | Busselton
# City not found. Skipping...
# Processing Record 5 of Set 1 | Bambous Virieux
# Processing Record 6 of Set 1 | Ushuaia
# Processing Record 7 of Set 1 | Lufilufi
# City not found. Skipping...
# Processing Record 8 of Set 1 | Nongpoh
# Processing Record 9 of Set 1 | Puerto Ayora
# Processing Record 10 of Set 1 | Gualeguaychu
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 11 of Set 1 | Albany
# Processing Record 12 of Set 1 | Qaanaaq
# Processing Record 13 of Set 1 | Atuona
# Processing Record 14 of Set 1 | Naze
# Processing Record 15 of Set 1 | San Quintin
# Processing Record 16 of Set 1 | Vangaindrano
# Processing Record 17 of Set 1 | Leningradskiy
# Processing Record 18 of Set 1 | Upernavik
# Processing Record 19 of Set 1 | Nikolayevsk-na-amure
# Processing Record 20 of Set 1 | Rikitea
# Processing Record 21 of Set 1 | Barda
# Processing Record 22 of Set 1 | Vaini
# Processing Record 23 of Set 1 | Mataura
# Processing Record 24 of Set 1 | Bluff
# Processing Record 25 of Set 1 | Georgetown
# Processing Record 26 of Set 1 | Longyearbyen
# Processing Record 27 of Set 1 | Bonavista
# City not found. Skipping...
# Processing Record 28 of Set 1 | Punta Arenas
# Processing Record 29 of Set 1 | Port Hawkesbury
# Processing Record 30 of Set 1 | Xining
# Processing Record 31 of Set 1 | Hasaki
# Processing Record 32 of Set 1 | Bredasdorp
# Processing Record 33 of Set 1 | Hobart
# Processing Record 34 of Set 1 | Evensk
# Processing Record 35 of Set 1 | Tabas
# Processing Record 36 of Set 1 | Morant Bay
# Processing Record 37 of Set 1 | Yellowknife
# Processing Record 38 of Set 1 | Port Elizabeth
# Processing Record 39 of Set 1 | Esna
# Processing Record 40 of Set 1 | Lafiagi
# Processing Record 41 of Set 1 | Khatanga
# Processing Record 42 of Set 1 | Sisimiut
# Processing Record 43 of Set 1 | Pisco
# Processing Record 44 of Set 1 | Conakry
# Processing Record 45 of Set 1 | Mar del Plata
# Processing Record 46 of Set 1 | Cape Town
# Processing Record 47 of Set 1 | Kahului
# Processing Record 48 of Set 1 | Otradnoye
# Processing Record 49 of Set 1 | Rincon
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 15 of Set 3 | The Valley
# Processing Record 16 of Set 3 | Corowa
# Processing Record 17 of Set 3 | Victoria
# Processing Record 18 of Set 3 | Ilulissat
# Processing Record 19 of Set 3 | Belmonte
# Processing Record 20 of Set 3 | Mount Isa
# Processing Record 21 of Set 3 | Groningen
# Processing Record 22 of Set 3 | Olinda
# Processing Record 23 of Set 3 | Porecatu
# Processing Record 24 of Set 3 | Okha
# City not found. Skipping...
# Processing Record 25 of Set 3 | Camargo
# Processing Record 26 of Set 3 | Nishihara
# Processing Record 27 of Set 3 | Bandarbeyla
# Processing Record 28 of Set 3 | Padang
# Processing Record 29 of Set 3 | Portland
# Processing Record 30 of Set 3 | Provideniya
# Processing Record 31 of Set 3 | Russell
# Processing Record 32 of Set 3 | Bria
# Processing Record 33 of Set 3 | Skjervoy
# Processing Record 34 of Set 3 | Dunedin
# Processing Record 35 of Set 3 | Syracuse
# Processing Record 36 of Set 3 | Rock Sound
# Processing Record 37 of Set 3 | Kodiak
# Processing Record 38 of Set 3 | Astoria
# Processing Record 39 of Set 3 | Rabo de Peixe
# Processing Record 40 of Set 3 | Port Lincoln
# Processing Record 41 of Set 3 | Mount Gambier
# City not found. Skipping...
# Processing Record 42 of Set 3 | Kikwit
# Processing Record 43 of Set 3 | Port Keats
# Processing Record 44 of Set 3 | Shelburne
# Processing Record 45 of Set 3 | Ambilobe
# Processing Record 46 of Set 3 | Castro
# Processing Record 47 of Set 3 | Cidreira
# Processing Record 48 of Set 3 | Paragominas
# Processing Record 49 of Set 3 | Krasnaya Gora
# Processing Record 0 of Set 4 | Alofi
# Processing Record 1 of Set 4 | Kruisfontein
# Processing Record 2 of Set 4 | Port Hedland
# Processing Record 3 of Set 4 | Christchurch
# Processing Record 4 of Set 4 | Chase
# Processing Record 5 of Set 4 | Tabou
# Processing Record 6 of Set 4 | Kutum
# Processing Record 7 of Set 4 | Iqaluit
# City not found. Skipping...
# Processing Record 8 of Set 4 | Abbeville
# Processing Record 9 of Set 4 | Dutse
# Processing Record 10 of Set 4 | Turukhansk
# Processing Record 11 of Set 4 | Kapaa
# Processing Record 12 of Set 4 | Airai
# Processing Record 13 of Set 4 | Abalak
# Processing Record 14 of Set 4 | Varanasi
# Processing Record 15 of Set 4 | Saskylakh
# Processing Record 16 of Set 4 | Chokurdakh
# Processing Record 17 of Set 4 | Los Llanos de Aridane
# Processing Record 18 of Set 4 | Fougamou
# Processing Record 19 of Set 4 | Najran
# Processing Record 20 of Set 4 | Cabo San Lucas
# Processing Record 21 of Set 4 | Sur
# Processing Record 22 of Set 4 | Arcachon
# Processing Record 23 of Set 4 | East London
# Processing Record 24 of Set 4 | Brownsville
# Processing Record 25 of Set 4 | Bonga
# Processing Record 26 of Set 4 | Xinqing
# Processing Record 27 of Set 4 | Katsuura
# Processing Record 28 of Set 4 | Salalah
# City not found. Skipping...
# Processing Record 29 of Set 4 | Snezhnogorsk
# Processing Record 30 of Set 4 | Puerto Baquerizo Moreno
# Processing Record 31 of Set 4 | Kaitangata
# Processing Record 32 of Set 4 | Nuuk
# Processing Record 33 of Set 4 | Montpelier
# Processing Record 34 of Set 4 | Kudahuvadhoo
# City not found. Skipping...
# Processing Record 35 of Set 4 | Sao Jose da Coroa Grande
# Processing Record 36 of Set 4 | Zyryanka
# Processing Record 37 of Set 4 | Hobyo
# Processing Record 38 of Set 4 | Cururupu
# Processing Record 39 of Set 4 | Walvis Bay
# Processing Record 40 of Set 4 | Norman Wells
# City not found. Skipping...
# Processing Record 41 of Set 4 | Sistranda
# Processing Record 42 of Set 4 | Luena
# Processing Record 43 of Set 4 | Sulangan
# Processing Record 44 of Set 4 | Abu Samrah
# Processing Record 45 of Set 4 | Adrar
# Processing Record 46 of Set 4 | Lata
# Processing Record 47 of Set 4 | Katherine
# Processing Record 48 of Set 4 | Wanaka
# Processing Record 49 of Set 4 | Tuatapere
# City not found. Skipping...
# Processing Record 0 of Set 5 | Saldanha
# Processing Record 1 of Set 5 | Haines Junction
# Processing Record 2 of Set 5 | Talara
# City not found. Skipping...
# Processing Record 3 of Set 5 | Cayenne
# Processing Record 4 of Set 5 | San Cristobal
# Processing Record 5 of Set 5 | Nabire
# Processing Record 6 of Set 5 | Lavrentiya
# Processing Record 7 of Set 5 | Brigantine
# Processing Record 8 of Set 5 | Sapele
# Processing Record 9 of Set 5 | Caravelas
# City not found. Skipping...
# Processing Record 10 of Set 5 | Upington
# Processing Record 11 of Set 5 | Hilo
# City not found. Skipping...
# Processing Record 12 of Set 5 | Kavieng
# Processing Record 13 of Set 5 | Kimbe
# Processing Record 14 of Set 5 | Klamath Falls
# Processing Record 15 of Set 5 | Chifeng
# Processing Record 16 of Set 5 | Samarai
# Processing Record 17 of Set 5 | Seminole
# City not found. Skipping...
# Processing Record 18 of Set 5 | Faya
# Processing Record 19 of Set 5 | Solnechnyy
# Processing Record 20 of Set 5 | Mahebourg
# Processing Record 21 of Set 5 | Tezu
# Processing Record 22 of Set 5 | Esperance
# Processing Record 23 of Set 5 | Terney
# Processing Record 24 of Set 5 | Vidalia
# Processing Record 25 of Set 5 | Buala
# Processing Record 26 of Set 5 | Bannu
# City not found. Skipping...
# Processing Record 27 of Set 5 | Surt
# Processing Record 28 of Set 5 | Cherskiy
# Processing Record 29 of Set 5 | Coos Bay
# Processing Record 30 of Set 5 | Warwick
# Processing Record 31 of Set 5 | Yafran
# Processing Record 32 of Set 5 | Bainbridge
# Processing Record 33 of Set 5 | Kontagora
# Processing Record 34 of Set 5 | Athens
# Processing Record 35 of Set 5 | Tongling
# Processing Record 36 of Set 5 | Antofagasta
# Processing Record 37 of Set 5 | Huarmey
# City not found. Skipping...
# Processing Record 38 of Set 5 | Praya
# Processing Record 39 of Set 5 | Tura
# City not found. Skipping...
# Processing Record 40 of Set 5 | San Carlos de Bariloche
# City not found. Skipping...
# Processing Record 41 of Set 5 | Thompson
# Processing Record 42 of Set 5 | Vila Velha
# Processing Record 43 of Set 5 | Razole
# Processing Record 44 of Set 5 | Pilar
# Processing Record 45 of Set 5 | Praia da Vitoria
# City not found. Skipping...
# Processing Record 46 of Set 5 | Porbandar
# Processing Record 47 of Set 5 | Lasa
# Processing Record 48 of Set 5 | Ranfurly
# Processing Record 49 of Set 5 | Nantucket
# Processing Record 0 of Set 6 | Samana
# Processing Record 1 of Set 6 | Lompoc
# Processing Record 2 of Set 6 | Ambunti
# Processing Record 3 of Set 6 | Caranavi
# Processing Record 4 of Set 6 | Boende
# City not found. Skipping...
# Processing Record 5 of Set 6 | Aklavik
# Processing Record 6 of Set 6 | Shimoda
# Processing Record 7 of Set 6 | Fuerte Olimpo
# Processing Record 8 of Set 6 | Paamiut
# Processing Record 9 of Set 6 | Catalina Foothills
# Processing Record 10 of Set 6 | Faanui
# Processing Record 11 of Set 6 | Suksun
# Processing Record 12 of Set 6 | Bilma
# Processing Record 13 of Set 6 | Makaha
# Processing Record 14 of Set 6 | Saint-Philippe
# Processing Record 15 of Set 6 | Itarema
# Processing Record 16 of Set 6 | Japura
# Processing Record 17 of Set 6 | Taoudenni
# Processing Record 18 of Set 6 | Shache
# Processing Record 19 of Set 6 | Serik
# Processing Record 20 of Set 6 | Hongjiang
# Processing Record 21 of Set 6 | Usinsk
# Processing Record 22 of Set 6 | Presidencia Roque Saenz Pena
# Processing Record 23 of Set 6 | Bethel
# Processing Record 24 of Set 6 | Brookings
# Processing Record 25 of Set 6 | Zhangjiakou
# Processing Record 26 of Set 6 | Westport
# Processing Record 27 of Set 6 | Herat
# Processing Record 28 of Set 6 | Manzanillo
# Processing Record 29 of Set 6 | Les Cayes
# Processing Record 30 of Set 6 | Plettenberg Bay
# Processing Record 31 of Set 6 | Nisia Floresta
# Processing Record 32 of Set 6 | Ca Mau
# Processing Record 33 of Set 6 | Egvekinot
# Processing Record 34 of Set 6 | Sechura
# Processing Record 35 of Set 6 | Petropavlovsk-Kamchatskiy
# Processing Record 36 of Set 6 | La Macarena
# Processing Record 37 of Set 6 | Mindelo
# Processing Record 38 of Set 6 | Juneau
# Processing Record 39 of Set 6 | Mayo
# Processing Record 40 of Set 6 | Udon Thani
# Processing Record 41 of Set 6 | Takaka
# Processing Record 42 of Set 6 | Grand Gaube
# Processing Record 43 of Set 6 | Trussville
# Processing Record 44 of Set 6 | Port Hardy
# Processing Record 45 of Set 6 | Northam
# Processing Record 46 of Set 6 | Bathsheba
# City not found. Skipping...
# Processing Record 47 of Set 6 | Constitucion
# Processing Record 48 of Set 6 | Maceio
# Processing Record 49 of Set 6 | Madang
# Processing Record 0 of Set 7 | Dobrinka
# Processing Record 1 of Set 7 | Ridgecrest
# Processing Record 2 of Set 7 | Ararat
# Processing Record 3 of Set 7 | Morondava
# Processing Record 4 of Set 7 | Napa
# City not found. Skipping...
# Processing Record 5 of Set 7 | Ola
# Processing Record 6 of Set 7 | Husavik
# Processing Record 7 of Set 7 | Darnah
# City not found. Skipping...
# Processing Record 8 of Set 7 | Umm Lajj
# City not found. Skipping...
# Processing Record 9 of Set 7 | Ossora
# Processing Record 10 of Set 7 | Ribeira Grande
# Processing Record 11 of Set 7 | Castelo do Piaui
# Processing Record 12 of Set 7 | Havre-Saint-Pierre
# Processing Record 13 of Set 7 | Torbay
# City not found. Skipping...
# Processing Record 14 of Set 7 | Plavinas
# Processing Record 15 of Set 7 | Moree
# Processing Record 16 of Set 7 | Aden
# Processing Record 17 of Set 7 | Srednekolymsk
# Processing Record 18 of Set 7 | Lubango
# Processing Record 19 of Set 7 | Sioux Lookout
# Processing Record 20 of Set 7 | Williamsburg
# Processing Record 21 of Set 7 | Ouahigouya
# Processing Record 22 of Set 7 | Makakilo City
# Processing Record 23 of Set 7 | Taywarah
# Processing Record 24 of Set 7 | Noumea
# Processing Record 25 of Set 7 | Guaruja
# Processing Record 26 of Set 7 | Houma
# Processing Record 27 of Set 7 | Khanpur
# Processing Record 28 of Set 7 | Nioro
# Processing Record 29 of Set 7 | Kaduqli
# Processing Record 30 of Set 7 | Boralday
# Processing Record 31 of Set 7 | Yuncheng
# Processing Record 32 of Set 7 | Lucapa
# Processing Record 33 of Set 7 | Grand Forks
# Processing Record 34 of Set 7 | Greencastle
# Processing Record 35 of Set 7 | College
# Processing Record 36 of Set 7 | Pandan
# Processing Record 37 of Set 7 | Ratnagiri
# Processing Record 38 of Set 7 | Maralal
# Processing Record 39 of Set 7 | Kifri
# Processing Record 40 of Set 7 | Tuy Hoa
# Processing Record 41 of Set 7 | Mnogovershinnyy
# City not found. Skipping...
# Processing Record 42 of Set 7 | Coquimbo
# Processing Record 43 of Set 7 | Santa Venera
# Processing Record 44 of Set 7 | Mikumi
# Processing Record 45 of Set 7 | Shieli
# Processing Record 46 of Set 7 | Kuala Terengganu
# Processing Record 47 of Set 7 | Inirida
# Processing Record 48 of Set 7 | Omboue
# Processing Record 49 of Set 7 | Kalmunai
# City not found. Skipping...
# Processing Record 0 of Set 8 | Bongandanga
# Processing Record 1 of Set 8 | Quatre Cocos
# Processing Record 2 of Set 8 | Harper
# Processing Record 3 of Set 8 | Guerrero Negro
# Processing Record 4 of Set 8 | Khandbari
# Processing Record 5 of Set 8 | Tianpeng
# City not found. Skipping...
# Processing Record 6 of Set 8 | Puri
# Processing Record 7 of Set 8 | Severo-Kurilsk
# Processing Record 8 of Set 8 | Senneterre
# City not found. Skipping...
# Processing Record 9 of Set 8 | Dehloran
# Processing Record 10 of Set 8 | Mbanza-Ngungu
# Processing Record 11 of Set 8 | Ostrovnoy
# Processing Record 12 of Set 8 | Manta
# City not found. Skipping...
# Processing Record 30 of Set 9 | Aguimes
# Processing Record 31 of Set 9 | Port Macquarie
# Processing Record 32 of Set 9 | Charters Towers
# Processing Record 33 of Set 9 | Usolye
# Processing Record 34 of Set 9 | Meulaboh
# Processing Record 35 of Set 9 | Sao Filipe
# Processing Record 36 of Set 9 | Barcelona
# Processing Record 37 of Set 9 | Isla Mujeres
# Processing Record 38 of Set 9 | Tyukalinsk
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 39 of Set 9 | Tagusao
# Processing Record 40 of Set 9 | Orange Cove
# Processing Record 41 of Set 9 | Gaozhou
# Processing Record 42 of Set 9 | Berlevag
# Processing Record 43 of Set 9 | Avera
# Processing Record 44 of Set 9 | Betare Oya
# Processing Record 45 of Set 9 | Sikonge
# Processing Record 46 of Set 9 | Sitka
# Processing Record 47 of Set 9 | Clermont
# Processing Record 48 of Set 9 | Tucurui
# Processing Record 49 of Set 9 | Guatire
# Processing Record 0 of Set 10 | Staryy Nadym
# Processing Record 1 of Set 10 | Bahia Blanca
# Processing Record 2 of Set 10 | Rio Gallegos
# Processing Record 3 of Set 10 | Aripuana
# Processing Record 4 of Set 10 | Penalva
# Processing Record 5 of Set 10 | Gat
# Processing Record 6 of Set 10 | La Crosse
# Processing Record 7 of Set 10 | Clyde River
# City not found. Skipping...
# Processing Record 8 of Set 10 | Luderitz
# Processing Record 9 of Set 10 | Ayr
# Processing Record 10 of Set 10 | Lima
# Processing Record 11 of Set 10 | Kamalpur
# Processing Record 12 of Set 10 | Nichlaul
# Processing Record 13 of Set 10 | Pevek
# Processing Record 14 of Set 10 | Farafangana
# Processing Record 15 of Set 10 | Oranjemund
# City not found. Skipping...
# Processing Record 16 of Set 10 | Vardo
# Processing Record 17 of Set 10 | Kamaishi
# Processing Record 18 of Set 10 | Bani Walid
# City not found. Skipping...
# Processing Record 19 of Set 10 | Kampene
# Processing Record 20 of Set 10 | Ucluelet
# Processing Record 21 of Set 10 | Rimini
# Processing Record 22 of Set 10 | Atar
# Processing Record 23 of Set 10 | Vikhorevka
# Processing Record 24 of Set 10 | Bilibino
# City not found. Skipping...
# Processing Record 25 of Set 10 | San Francisco
# City not found. Skipping...
# Processing Record 26 of Set 10 | Arman
# Processing Record 27 of Set 10 | Tevaitoa
# City not found. Skipping...
# Processing Record 28 of Set 10 | Gold Coast
# Processing Record 29 of Set 10 | Vodnyy
# Processing Record 30 of Set 10 | Hayden
# Processing Record 31 of Set 10 | Pandamatenga
# Processing Record 32 of Set 10 | Datong
# City not found. Skipping...
# Processing Record 33 of Set 10 | Praia
# Processing Record 34 of Set 10 | Camocim
# Processing Record 35 of Set 10 | Nandi Hills
# Processing Record 36 of Set 10 | Te Anau
# Processing Record 37 of Set 10 | Chiredzi
# Processing Record 38 of Set 10 | Lebu
# Processing Record 39 of Set 10 | Vorotynets
# Processing Record 40 of Set 10 | Maniitsoq
# Processing Record 41 of Set 10 | Sawakin
# Processing Record 42 of Set 10 | Poya
# Processing Record 43 of Set 10 | Saint-Avold
# Processing Record 44 of Set 10 | Yerbogachen
# Processing Record 45 of Set 10 | Booue
# Processing Record 46 of Set 10 | Luanda
# Processing Record 47 of Set 10 | Goderich
# Processing Record 48 of Set 10 | Kostyantynivka
# Processing Record 49 of Set 10 | Price
# Processing Record 0 of Set 11 | Kipushi
# Processing Record 1 of Set 11 | Talnakh
# Processing Record 2 of Set 11 | Junin
# Processing Record 3 of Set 11 | Liverpool
# Processing Record 4 of Set 11 | Pacifica
# Processing Record 5 of Set 11 | Neuquen
# Processing Record 6 of Set 11 | Nyrob
# Processing Record 7 of Set 11 | Dumas
# City not found. Skipping...
# Processing Record 8 of Set 11 | Aksu
# Processing Record 9 of Set 11 | Tilichiki
# Processing Record 10 of Set 11 | Shu
# Processing Record 11 of Set 11 | Itupiranga
# Processing Record 12 of Set 11 | Sao Joao da Barra
# Processing Record 13 of Set 11 | Araouane
# Processing Record 14 of Set 11 | Namanga
# Processing Record 15 of Set 11 | Deputatskiy
# Processing Record 16 of Set 11 | Glenwood Springs
# Processing Record 17 of Set 11 | Alta Floresta
# Processing Record 18 of Set 11 | Ajdabiya
# Processing Record 19 of Set 11 | Mahibadhoo
# Processing Record 20 of Set 11 | Souillac
# Processing Record 21 of Set 11 | Namatanai
# Processing Record 22 of Set 11 | Teya
# City not found. Skipping...
# Processing Record 23 of Set 11 | Zhigansk
# Processing Record 24 of Set 11 | Sola
# Processing Record 25 of Set 11 | Tarko-Sale
# Processing Record 26 of Set 11 | Sinnamary
# Processing Record 27 of Set 11 | Tanout
# Processing Record 28 of Set 11 | Labuhan
# Processing Record 29 of Set 11 | Valley City
# Processing Record 30 of Set 11 | Taguatinga
# Processing Record 31 of Set 11 | Sao Miguel do Iguacu
# Processing Record 32 of Set 11 | Cepu
# Processing Record 33 of Set 11 | Rafai
# Processing Record 34 of Set 11 | Yaan
# Processing Record 35 of Set 11 | Puerto Parra
# Processing Record 36 of Set 11 | Zmeinogorsk
# Processing Record 37 of Set 11 | Vila Franca do Campo
# Processing Record 38 of Set 11 | Djambala
# Processing Record 39 of Set 11 | Chegdomyn
# Processing Record 40 of Set 11 | Burnie
# Processing Record 41 of Set 11 | Milkovo
# Processing Record 42 of Set 11 | Sabzevar
# Processing Record 43 of Set 11 | Itabirito
# Processing Record 44 of Set 11 | Kukuna
# Processing Record 45 of Set 11 | Aquiraz
# Processing Record 46 of Set 11 | Marawi
# Processing Record 47 of Set 11 | Trincomalee
# Processing Record 48 of Set 11 | Jumla
# Processing Record 49 of Set 11 | Vestmanna
# City not found. Skipping...
# ---------------------------
# Data Retrieval Complete
# ---------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather = pd.DataFrame()
weather['City'] = city_name
weather['Cloudiness'] = ''
weather['Country'] = ''
weather['Date'] = ''
weather['Humidity'] = ''
weather['Lat'] = ''
weather['Lng'] = ''
weather['Max Temp'] = ''
weather['Wind Speed'] = ''

cloudlist = []
countrylist = []
datelist = []
humidlist = []
latlist = []
lnglist = []
max_templist = []
windlist = []

# %%
for index,row in weather.iterrows():
    city = row['City']
    response = requests.get(query_url + city).json()
    cloud = response['clouds']['all']
    cloudlist.append(cloud)
    country = response['sys']['country']
    countrylist.append(country)
    date = response['dt']
    datelist.append(date)
    humid = response['main']['humidity']
    humidlist.append(humid)
    lat = response['coord']['lat']
    latlist.append(lat)
    lng = response['coord']['lon']
    lnglist.append(lng)
    max_temp = response['main']['temp_max']
    max_templist.append(max_temp)
    wind = response['wind']['speed']
    windlist.append(wind)
    time.sleep(1)
weather['Cloudiness'] = cloudlist
weather['Country'] = countrylist
weather['Date'] = datelist
weather['Humidity'] = humidlist
weather['Lat'] = latlist
weather['Lng'] = lnglist
weather['Max Temp'] = max_templist
weather['Wind Speed'] = windlist

# %%
weather.to_csv('weather.csv')
weather.count()
# Out:
# City          550
# Cloudiness    550
# Country       550
# Date          550
# Humidity      550
# Lat           550
# Lng           550
# Max Temp      550
# Wind Speed    550
# dtype: int64

# %%
weather.head()
# Out:
#         City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0  Carnarvon           0      ZA  1548097342        10 -30.97   22.13
# 1   Hermanus           0      ZA  1548097348        50 -34.42   19.24
# 2     Barrow           0      AR  1548097349        38 -38.31  -60.23
# 3  Hithadhoo          44      MV  1548097350       100  -0.60   73.08
# 4  Busselton          76      AU  1548097361       100 -33.64  115.35
#
#    Max Temp  Wind Speed
# 0     80.82       10.45
# 1     66.60        2.95
# 2     83.34       10.45
# 3     82.44        4.52
# 4     65.29       18.50

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
date1 = datetime.fromtimestamp(weather['Date'][0])
date1 = date1.strftime('%m/%d/%Y')
plt.scatter(weather['Lat'],weather['Max Temp'],edgecolors='black')
plt.grid()
plt.title('City Latitude vs. Max Temperature (' + date1 + ')')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4271ab3e1b33> in <module>()
# ----> 1 date1 = datetime.fromtimestamp(weather['Date'][0])
#       2 date1 = date1.strftime('%m/%d/%Y')
#       3 plt.scatter(weather['Lat'],weather['Max Temp'],edgecolors='black')
#       4 plt.grid()
#       5 plt.title('City Latitude vs. Max Temperature (' + date1 + ')')
#
# NameError: name 'datetime' is not defined

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather['Lat'],weather['Humidity'],edgecolors='black')
plt.grid()
plt.title('City Latitude vs. Humidity (' + date1 + ')')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.show()

# %%
weather.loc[weather['Humidity']>100,:]
# Out:
#        City  Cloudiness Country        Date  Humidity   Lat    Lng  Max Temp  \
# 202  Talara           0      PE  1548093600       290 -4.58 -81.27      62.6
#
#      Wind Speed
# 202       10.29

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather['Lat'],weather['Cloudiness'],edgecolors='black')
plt.grid()
plt.title('City Latitude vs. Cloudiness (' + date1 + ')')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather['Lat'],weather['Wind Speed'],edgecolors='black')
plt.grid()
plt.title('City Latitude vs. Wind Speed (' + date1 + ')')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.show()

# %% [markdown]
# ## Analysis
#
# The southern hemisphere is warmer on average than the northern hemisphere, which makes sense because it is summer in the southern hemisphere.
#
# Most humidity percentages are between 50 and 100 percent. There is one data point that has 290 percent humidity. This is an error in the data, as that city has humidity of 57 percent, currently.
#
# The majority of wind speeds are between 0 and 10 mph. Four of the top five highest wind speeds occur in the northern hemisphere.
